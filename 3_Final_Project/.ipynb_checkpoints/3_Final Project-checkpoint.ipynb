# %% [markdown]
# <h1 style="color:blue" align="center"> Final Project </h1>
# <h2 style="color:green" align="center"> Predicting Adverse Drug reactions with Machine Learning </h2>

# %% [markdown]
# -----------

# %% [markdown]
# ### Company : Technocolabs
# ### Role : Machine Learning Intern
#
# ### Author
# Anuganti Suresh

# %% [markdown]
# ---------------

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# |Variable                                                                |Definition                                   |
# |------------------------------------------------------------------------|---------------------------------------------|
# |smiles                                                                  |--------                                     |
# |Hepatobiliary disorders                                                 |--------                                     |
# |Metabolism and nutrition disorders                                      |------                                       |
# |Eye disorders       	                                                 |-----                                        |
# |Musculoskeletal and connective tissue disorders                      	 |------------                                 |
# |Gastrointestinal disorders                 	                         |------------                                 |
# |Immune system disorders                     	                         |-----                                        |
# |Reproductive system and breast disorders      	                         |----------                                   |
# |Neoplasms benign, malignant and unspecified (incl cysts and polyps)     |----------                                   |
# |General disorders and administration site conditions      	             |----------                                   |
# |Endocrine disorders                                                     |----------                                   |
# |Surgical and medical procedures                                         |----------                                   |
# |Vascular disorders                                                      |----------                                   |
# |Blood and lymphatic system disorders                                    |----------                                   |
# |Skin and subcutaneous tissue disorders                                  |------------                                 |
# |Congenital, familial and genetic disorders                    	         |-----------                                  |
# |Infections and infestations                 	                         |-----------                                  |
# |Respiratory, thoracic and mediastinal disorders                         |-----------                                  |
# |Psychiatric disorders                                                   |-----------                                  |
# |Renal and urinary disorders                                             |-----------                                  |
# |Pregnancy, puerperium and perinatal conditions                          |-----------                                  |
# |Ear and labyrinth disorders                                             |-----------                                  |
# |Cardiac disorders                                                       |-----------                                  |
# |Nervous system disorders                                                |-----------                                  |
# |Injury, poisoning and procedural complications                          |-----------                                  |

# %% [markdown]
# ---------------

# %% [markdown]
# <h2 style="color:blue" align="left"> 1. Import necessary Libraries </h2>

# %%
# Read Data
import numpy as np                     # Linear Algebra (calculate the mean and standard deviation)
import pandas as pd                    # manipulate data, data processing, load csv file I/O (e.g. pd.read_csv)

# Visualization
import seaborn as sns                  # Visualization using seaborn
import matplotlib.pyplot as plt        # Visualization using matplotlib
# %matplotlib inline

# style
plt.style.use("fivethirtyeight")       # Set Graphs Background style using matplotlib
sns.set_style("darkgrid")              # Set Graphs Background style using seaborn

import warnings                        # Ignore Warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <h2 style="color:blue" align="left"> 2. Load data </h2>

# %%
df1 = pd.read_csv("../3_Final_Project/datasets/offside_socs_modified.csv")
df2 = pd.read_csv("../3_Final_Project/datasets/offsides_socs.zip")
df3 = pd.read_csv("../3_Final_Project/datasets/sider.csv")

# %%
display(df1.shape)
display(df2.shape)
display(df3.shape)
# Out:
# (1332, 25)
# (438801, 15)
# (1427, 28)

# %%
display(df1.columns)
display(df3.columns)
# Out:
# Index(['smiles', 'Hepatobiliary disorders',
#        'Metabolism and nutrition disorders', 'Eye disorders',
#        'Musculoskeletal and connective tissue disorders',
#        'Gastrointestinal disorders', 'Immune system disorders',
#        'Reproductive system and breast disorders',
#        'Neoplasms benign, malignant and unspecified (incl cysts and polyps)',
#        'General disorders and administration site conditions',
#        'Endocrine disorders', 'Surgical and medical procedures',
#        'Vascular disorders', 'Blood and lymphatic system disorders',
#        'Skin and subcutaneous tissue disorders',
#        'Congenital, familial and genetic disorders',
#        'Infections and infestations',
#        'Respiratory, thoracic and mediastinal disorders',
#        'Psychiatric disorders', 'Renal and urinary disorders',
#        'Pregnancy, puerperium and perinatal conditions',
#        'Ear and labyrinth disorders', 'Cardiac disorders',
#        'Nervous system disorders',
# ...

# %% [raw]
# df3 ---> 'Product issues', 'Investigations' and 'Social circumstances'

# %%
df1.head()
# Out:
#                                               smiles  Hepatobiliary disorders  \
# 0              CC12CCC3C(C1CCC2=O)CC=C4C3(CCC(C4)O)C                        1
# 1                            C[N+](C)(C)CC(CC(=O)O)O                        1
# 2                                       C(CC(=O)O)CN                        1
# 3  C1C(N(C2=C(N1)NC(=NC2=O)N)C=O)CNC3=CC=C(C=C3)C...                        1
# 4            CCCCCC(C=CC1C(CC(=O)C1CC=CCCCC(=O)O)O)O                        1
#
#    Metabolism and nutrition disorders  Eye disorders  \
# 0                                   1              0
# 1                                   1              1
# 2                                   1              1
# 3                                   1              1
# 4                                   0              0
#
#    Musculoskeletal and connective tissue disorders  \
# 0                                                1
# 1                                                1
# ...

# %%
df2.head()
# Out:
#       stitch_id                    drug   umls_id                  event  \
# 0  CID000000076  dehydroepiandrosterone  C0000737         abdominal pain
# 1  CID000000076  dehydroepiandrosterone  C0001622        hyperadrenalism
# 2  CID000000076  dehydroepiandrosterone  C0001623  adrenal insufficiency
# 3  CID000000076  dehydroepiandrosterone  C0002792  anaphylactic reaction
# 4  CID000000076  dehydroepiandrosterone  C0002940               aneurysm
#
#           rr    log2rr  t_statistic        pvalue  observed  expected  \
# 0   2.250000  1.169925     6.537095  6.156712e-07         9  4.000000
# 1  11.000000  3.459432     4.782699  1.644408e-03         2  0.181818
# 2   2.200000  1.137504     4.315199  9.884952e-03         2  0.909091
# 3   2.588235  1.371969     4.590918  3.355380e-03         4  1.545455
# 4   7.333333  2.874469     4.598374  3.399457e-03         2  0.272727
#
#    bg_correction  sider  future_aers  medeffect                         SOC
# ...

# %%
df3.head()
# Out:
#                                               smiles  Hepatobiliary disorders  \
# 0                                    C(CNCCNCCNCCN)N                        1
# 1  CC(C)(C)C1=CC(=C(C=C1NC(=O)C2=CNC3=CC=CC=C3C2=...                        0
# 2  CC[C@]12CC(=C)[C@H]3[C@H]([C@@H]1CC[C@]2(C#C)O...                        0
# 3    CCC12CC(=C)C3C(C1CC[C@]2(C#C)O)CCC4=CC(=O)CCC34                        1
# 4             C1C(C2=CC=CC=C2N(C3=CC=CC=C31)C(=O)N)O                        1
#
#    Metabolism and nutrition disorders  Product issues  Eye disorders  \
# 0                                   1               0              0
# 1                                   1               0              0
# 2                                   1               0              1
# 3                                   1               0              1
# 4                                   1               0              1
#
#    Investigations  Musculoskeletal and connective tissue disorders  \
# ...

# %%
todrop = ["Product issues", "Investigations", "Social circumstances"]
df3.drop(todrop, axis=1, inplace=True)

# %%
df = pd.concat([df1, df3])
df.head()
# Out:
#                                               smiles  Hepatobiliary disorders  \
# 0              CC12CCC3C(C1CCC2=O)CC=C4C3(CCC(C4)O)C                        1
# 1                            C[N+](C)(C)CC(CC(=O)O)O                        1
# 2                                       C(CC(=O)O)CN                        1
# 3  C1C(N(C2=C(N1)NC(=NC2=O)N)C=O)CNC3=CC=C(C=C3)C...                        1
# 4            CCCCCC(C=CC1C(CC(=O)C1CC=CCCCC(=O)O)O)O                        1
#
#    Metabolism and nutrition disorders  Eye disorders  \
# 0                                   1              0
# 1                                   1              1
# 2                                   1              1
# 3                                   1              1
# 4                                   0              0
#
#    Musculoskeletal and connective tissue disorders  \
# 0                                                1
# 1                                                1
# ...

# %%
df.tail()
# Out:
#                                                  smiles  \
# 1422  C[C@H]1CN(CC[C@@]1(C)C2=CC(=CC=C2)O)C[C@H](CC3...
# 1423  CC[C@@H]1[C@@]2([C@@H]([C@@H](C(=O)[C@@H](C[C@...
# 1424  CCOC1=CC=C(C=C1)CC2=C(C=CC(=C2)[C@H]3[C@@H]([C...
# 1425  C1CN(CCC1N2C3=CC=CC=C3NC2=O)CCCC(C4=CC=C(C=C4)...
# 1426       CCC(=O)C(CC(C)N(C)C)(C1=CC=CC=C1)C2=CC=CC=C2
#
#       Hepatobiliary disorders  Metabolism and nutrition disorders  \
# 1422                        0                                   1
# 1423                        1                                   1
# 1424                        1                                   1
# 1425                        0                                   1
# 1426                        1                                   1
#
#       Eye disorders  Musculoskeletal and connective tissue disorders  \
# 1422              0                                                1
# 1423              1                                                1
# ...

# %%
df.shape
# Out:
# (2759, 25)

# %% [markdown]
# <h2 style="color:blue" align="left"> 3. EDA (Exploratory Data Analysis) </h2>

# %%
df1.isnull().sum()
# Out:
# smiles                                                                 0
# Hepatobiliary disorders                                                0
# Metabolism and nutrition disorders                                     0
# Eye disorders                                                          0
# Musculoskeletal and connective tissue disorders                        0
# Gastrointestinal disorders                                             0
# Immune system disorders                                                0
# Reproductive system and breast disorders                               0
# Neoplasms benign, malignant and unspecified (incl cysts and polyps)    0
# General disorders and administration site conditions                   0
# Endocrine disorders                                                    0
# Surgical and medical procedures                                        0
# Vascular disorders                                                     0
# ...

# %%
df2.isnull().sum()
# Out:
# stitch_id            0
# drug                 0
# umls_id              0
# event                0
# rr                   0
# log2rr               0
# t_statistic          0
# pvalue               0
# observed             0
# expected             0
# bg_correction        0
# sider                0
# future_aers          0
# medeffect            0
# SOC              14298
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# smiles                                                                 0
# Hepatobiliary disorders                                                0
# Metabolism and nutrition disorders                                     0
# Product issues                                                         0
# Eye disorders                                                          0
# Investigations                                                         0
# Musculoskeletal and connective tissue disorders                        0
# Gastrointestinal disorders                                             0
# Social circumstances                                                   0
# Immune system disorders                                                0
# Reproductive system and breast disorders                               0
# Neoplasms benign, malignant and unspecified (incl cysts and polyps)    0
# General disorders and administration site conditions                   0
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df2['drug'].value_counts()
# Out:
# pamidronate                2206
# zoledronic acid            2053
# retinoic acid              1865
# chlorhexidine gluconate    1711
# ribavirin                  1639
#                            ...
# pentobarbital                39
# hexetidine                   36
# EMD 121974                   32
# carbamide peroxide           21
# Tiamate                       4
# Name: drug, Length: 1332, dtype: int64

# %%
plt.figure(figsize=(15,10))
df2['drug'].value_counts().sort_values(ascending=True).plot.bar()
plt.show()

# %% [markdown]
# <h2 style="color:blue" align="left"> 6. Model building and Evaluation </h2>

# %% [markdown]
# ### a) Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB()
classifier.fit(X_train, y_train)

# %% [markdown]
# ### b) Random Forest

# %%
# Fitting Random Forest Classification to the Training set 
from sklearn.ensemble import RandomForestClassifier 
  
# n_estimators can be said as number of trees, experiment with n_estimators to get better results  
model = RandomForestClassifier(n_estimators = 100, criterion = 'entropy', random_state = 7) 
model.fit(X_train, y_train)

# %% [markdown]
# ### c) Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X_train, y_train)

# %% [markdown]
# ### d) SVM

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train)
